# %% [markdown]
# # Module 2 Summative Lab
#
# ## Introduction
#
# For today's section, we're going to work on a single big lab to apply everything we've learned in Module 2!
#
# ## About This Lab
#
# A quick note before getting started--this lab isn't like other labs you seen so far. This lab is meant to take ~8 hours to complete, so it's much longer and more challenging that the average labs you've seen so far. If you feel like this lab is challenging or that you might be struggling a bit, don't fret--that's by design! With everything we've learned about Web Scraping, APIs, and Databases, the best way to test our knowledge of it is to build something substantial!
#
# ## The Project
#
# In this lab, we're going to make use of everything we've learned about APIs, databases, and Object-Oriented Programming to **_Extract, Transform, and Load_** (or **_ETL_**, for short) some data from a SQL database into a MongoDB Database.
#
# You'll find a database containing information about soccer teams and the matches they've played in the file `database.sqlite`. For this project, our goal is to get the data we think is important from this SQL database, do some calculations and data transformation, and then store everything in a MongoDB database.
#
# Let's get into the specifics of this project.
#
# ### The Goal
#
# Start by examining the data dictionary for the SQL database we'll be working with, which comes from this [kaggle page](https://www.kaggle.com/laudanum/footballdelphi).  Familiarize yourself with the tables it contains, and what each column means. We'll be using this database to get data on each soccer team, calculate some summary statistics, and then store each in a MongoDB database.
#
# Upon completion of this lab, each unique team in this dataset should have a record in the MongoDB instance containing the following information:
#
# * The name of the team
# * The total number of goals scored by the team during the 2011 season
# * The total number of wins the team earned during the 2011 season
# * A histogram visualization of the team's wins and losses for the 2011 season (store the visualization directly)
# * The team's win percentage on days where it was raining during games in the 2011 season.
#
# #### Getting the Weather Data
#
# Note that for this last calculation, you'll need to figure out if it was raining or not during the game. The database itself does not contain this information, but it does contain the date on which the game was played. For this, you'll need to use the [DarkSky API](https://darksky.net/dev) to get the historical weather data for that day. Note that each game is played in a different location, and this information is not contained in our SQL database. However, the teams in this database are largely german, so go ahead and just use the weather in Berlin, Germany as a proxy for this information. If it was raining in Berlin on the day the game was played, count that as rain game--**_you do not need to try and figure out the actual weather at each game's location, because we don't have that information!_**
#
# #### NOTE: The DarkSky API is limited to 1000 free API calls a day, so be sure to test your model on very small samples. Otherwise, you'll hit the rate limit!
#
# ## Project Architecture
#
# Unlike previous labs, this lab is more open-ended, and will require you to make design decisions and plan out your strategy for building a system with this many working parts. However, **_using Object-Oriented Programming is a requirement for this project--you must create at least 2 separate, well structured classes in your solution!_** Although it may seem easier to "just start coding", this is a classic beginner's mistake. Instead, think about separating out the different functionalities you'll need to reach your goal, and then build classes to handle each. For instance, at minimum, you'll need to:
#
# * Query the SQL database
# * Calculate summary statistics
# * Get the weather data from the DarkSky API
# * Load the data into MongoDB
#
# We **_strongly recommend_** you consider creating separate classes for handling at least some of these of these tasks.  Be sure to plan the inputs, outputs, and methods for each class before you begin coding!
#
# **_NOTE:_** We have provided some empty classes below. You are welcome to delete them and use a different architecture for this project if you so choose.  You do not have to use each of them, they are just there to give you an idea of what you could sorts of classes you may want to consider using.
#
# ### Rapid Prototyping and Refactoring
#
# It's totally okay to try to get a task working without using OOP. For instance, when experimenting with the DarkSky API for getting historical weather data, it makes sense to just write the code in the cells and rapidly iterate until you get it all working. However, once you get it working, you're not done--you should then **_Refactor_** your code into functions or classes to make your code more modular, reusable, understandable, and maintainable!
#
# In short--do what you need to do to get each separate piece of functionality working, and then refactor it into a class after you've figured it out!
#
# ### Some Final Advice
#
# You haven't built anything this big or complex thus far, so you may not yet fully realize how much trial and error goes into it. If your code keeps breaking, resist the urge to get frustrated, and just keep working. Software development is an iterative process!  No one writes perfect code that works the first time for something this involved. You're going to run into _a lot_ of small errors in this project, right up until the point where it just works, and then you're done! However, you can reduce these errors by planning out your code, and thinking about how all of the pieces fit together before you begin coding. Once you have some basic understanding of how it all will work, then you'll know what you need to build, and then all that is left is to build it!
#
# In short:
#
# * Plan ahead--you'll thank yourself later!
# * Errors and broken code aren't bad, they're normal.
# * Keep working, and stay confident--you can do this!
#
# Good luck--we look forward to seeing your completed project!

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# We've scaffolded your classes in the provided lib.py file
import requests
import json
from lib import MongoHandler, WeatherGetter

# %%
calll = WeatherGetter()
calll

# %%
m = calll.weather_getter()

# %%
m.json()
# Out:
# {'latitude': 37.8267,
#  'longitude': -122.4233,
#  'timezone': 'America/Los_Angeles',
#  'currently': {'time': 1572454367,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 55.67,
#   'apparentTemperature': 55.67,
#   'dewPoint': 9.53,
#   'humidity': 0.16,
#   'pressure': 1020.7,
#   'windSpeed': 10.19,
#   'windGust': 14.36,
#   'windBearing': 76,
#   'cloudCover': 0,
#   'uvIndex': 2,
#   'visibility': 9.098,
#   'ozone': 268.1},
#  'minutely': {'summary': 'Clear for the hour.',
#   'icon': 'clear-day',
#   'data': [{'time': 1572454320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454920, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572454980, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455040, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455100, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455160, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455220, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455280, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455340, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455400, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455460, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455520, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455580, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455640, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455700, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455760, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455820, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455880, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572455940, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456000, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456060, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456120, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456180, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456240, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456300, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456360, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456420, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456480, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456540, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456600, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456660, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456720, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456780, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456840, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456900, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572456960, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457020, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457080, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457140, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457200, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457260, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457320, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457380, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457440, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457500, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457560, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457620, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457680, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457740, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457800, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457860, 'precipIntensity': 0, 'precipProbability': 0},
#    {'time': 1572457920, 'precipIntensity': 0, 'precipProbability': 0}]},
#  'hourly': {'summary': 'Clear throughout the day.',
#   'icon': 'clear-day',
#   'data': [{'time': 1572451200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 53.15,
#     'apparentTemperature': 53.15,
#     'dewPoint': 10.98,
#     'humidity': 0.18,
#     'pressure': 1020.7,
#     'windSpeed': 9.82,
#     'windGust': 16.09,
#     'windBearing': 80,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 9.669,
#     'ozone': 268.8},
#    {'time': 1572454800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.03,
#     'apparentTemperature': 56.03,
#     'dewPoint': 9.4,
#     'humidity': 0.15,
#     'pressure': 1020.8,
#     'windSpeed': 10.22,
#     'windGust': 14.15,
#     'windBearing': 75,
#     'cloudCover': 0,
#     'uvIndex': 2,
#     'visibility': 9.096,
#     'ozone': 268},
#    {'time': 1572458400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.83,
#     'apparentTemperature': 58.83,
#     'dewPoint': 9.69,
#     'humidity': 0.14,
#     'pressure': 1021.8,
#     'windSpeed': 10.38,
#     'windGust': 12.98,
#     'windBearing': 69,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 267.8},
#    {'time': 1572462000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0005,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 60.12,
#     'apparentTemperature': 60.12,
#     'dewPoint': 10.01,
#     'humidity': 0.14,
#     'pressure': 1021.8,
#     'windSpeed': 10.15,
#     'windGust': 14.24,
#     'windBearing': 63,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 268.2},
#    {'time': 1572465600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.67,
#     'apparentTemperature': 62.67,
#     'dewPoint': 12.27,
#     'humidity': 0.14,
#     'pressure': 1020.7,
#     'windSpeed': 9.22,
#     'windGust': 13.9,
#     'windBearing': 60,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 269},
#    {'time': 1572469200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0015,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 65.15,
#     'apparentTemperature': 65.15,
#     'dewPoint': 16.12,
#     'humidity': 0.15,
#     'pressure': 1021.2,
#     'windSpeed': 7.84,
#     'windGust': 11.27,
#     'windBearing': 55,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 269.6},
#    {'time': 1572472800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.99,
#     'apparentTemperature': 66.99,
#     'dewPoint': 19.83,
#     'humidity': 0.16,
#     'pressure': 1021.2,
#     'windSpeed': 6.04,
#     'windGust': 8.69,
#     'windBearing': 55,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 269.9},
#    {'time': 1572476400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.96,
#     'apparentTemperature': 67.96,
#     'dewPoint': 24.59,
#     'humidity': 0.19,
#     'pressure': 1020.7,
#     'windSpeed': 5.1,
#     'windGust': 8.02,
#     'windBearing': 40,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 270},
#    {'time': 1572480000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.81,
#     'apparentTemperature': 67.81,
#     'dewPoint': 27.66,
#     'humidity': 0.22,
#     'pressure': 1021.7,
#     'windSpeed': 4.16,
#     'windGust': 7.13,
#     'windBearing': 12,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 269.9},
#    {'time': 1572483600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.77,
#     'apparentTemperature': 65.77,
#     'dewPoint': 30.54,
#     'humidity': 0.27,
#     'pressure': 1022,
#     'windSpeed': 3.58,
#     'windGust': 6.99,
#     'windBearing': 5,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 269.6},
#    {'time': 1572487200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.63,
#     'apparentTemperature': 62.63,
#     'dewPoint': 32.89,
#     'humidity': 0.33,
#     'pressure': 1021.9,
#     'windSpeed': 3.31,
#     'windGust': 5.58,
#     'windBearing': 15,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 269.1},
#    {'time': 1572490800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.99,
#     'apparentTemperature': 60.99,
#     'dewPoint': 33.28,
#     'humidity': 0.35,
#     'pressure': 1022.9,
#     'windSpeed': 3.13,
#     'windGust': 4.63,
#     'windBearing': 19,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 268.7},
#    {'time': 1572494400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.09,
#     'apparentTemperature': 60.09,
#     'dewPoint': 32.96,
#     'humidity': 0.36,
#     'pressure': 1022.7,
#     'windSpeed': 3.07,
#     'windGust': 4.28,
#     'windBearing': 31,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 268.3},
#    {'time': 1572498000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.29,
#     'apparentTemperature': 60.29,
#     'dewPoint': 31.04,
#     'humidity': 0.33,
#     'pressure': 1023,
#     'windSpeed': 3.07,
#     'windGust': 4.78,
#     'windBearing': 26,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 267.9},
#    {'time': 1572501600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.68,
#     'apparentTemperature': 59.68,
#     'dewPoint': 30.76,
#     'humidity': 0.33,
#     'pressure': 1023.4,
#     'windSpeed': 3.26,
#     'windGust': 5,
#     'windBearing': 27,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 267.4},
#    {'time': 1572505200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.89,
#     'apparentTemperature': 58.89,
#     'dewPoint': 30.32,
#     'humidity': 0.34,
#     'pressure': 1023.4,
#     'windSpeed': 3.6,
#     'windGust': 5.45,
#     'windBearing': 40,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 266.6},
#    {'time': 1572508800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.02,
#     'apparentTemperature': 58.02,
#     'dewPoint': 29.77,
#     'humidity': 0.34,
#     'pressure': 1023.3,
#     'windSpeed': 4.05,
#     'windGust': 6.03,
#     'windBearing': 48,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 265.8},
#    {'time': 1572512400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.17,
#     'apparentTemperature': 57.17,
#     'dewPoint': 29.13,
#     'humidity': 0.34,
#     'pressure': 1023.2,
#     'windSpeed': 4.45,
#     'windGust': 6.54,
#     'windBearing': 47,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 265.2},
#    {'time': 1572516000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.29,
#     'apparentTemperature': 56.29,
#     'dewPoint': 28.5,
#     'humidity': 0.34,
#     'pressure': 1023.1,
#     'windSpeed': 4.7,
#     'windGust': 6.86,
#     'windBearing': 45,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 265.3},
#    {'time': 1572519600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.32,
#     'apparentTemperature': 55.32,
#     'dewPoint': 27.7,
#     'humidity': 0.34,
#     'pressure': 1023,
#     'windSpeed': 4.97,
#     'windGust': 7.09,
#     'windBearing': 46,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 265.8},
#    {'time': 1572523200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.11,
#     'apparentTemperature': 54.11,
#     'dewPoint': 26.65,
#     'humidity': 0.34,
#     'pressure': 1023,
#     'windSpeed': 5.17,
#     'windGust': 7.27,
#     'windBearing': 50,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 266},
#    {'time': 1572526800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 53.24,
#     'apparentTemperature': 53.24,
#     'dewPoint': 25.14,
#     'humidity': 0.33,
#     'pressure': 1023,
#     'windSpeed': 5.39,
#     'windGust': 7.36,
#     'windBearing': 52,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 265.3},
#    {'time': 1572530400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 52.44,
#     'apparentTemperature': 52.44,
#     'dewPoint': 23.36,
#     'humidity': 0.32,
#     'pressure': 1023.2,
#     'windSpeed': 5.61,
#     'windGust': 7.49,
#     'windBearing': 55,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 264.1},
#    {'time': 1572534000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0.0003,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperature': 52.35,
#     'apparentTemperature': 52.35,
#     'dewPoint': 21.53,
#     'humidity': 0.3,
#     'pressure': 1023.5,
#     'windSpeed': 5.75,
#     'windGust': 7.67,
#     'windBearing': 56,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 263.3},
#    {'time': 1572537600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.54,
#     'apparentTemperature': 54.54,
#     'dewPoint': 19.02,
#     'humidity': 0.25,
#     'pressure': 1023.8,
#     'windSpeed': 5.8,
#     'windGust': 8.09,
#     'windBearing': 59,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 262.9},
#    {'time': 1572541200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.16,
#     'apparentTemperature': 58.16,
#     'dewPoint': 16.15,
#     'humidity': 0.19,
#     'pressure': 1024.1,
#     'windSpeed': 5.54,
#     'windGust': 8.66,
#     'windBearing': 61,
#     'cloudCover': 0,
#     'uvIndex': 2,
#     'visibility': 10,
#     'ozone': 262.8},
#    {'time': 1572544800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 61.15,
#     'apparentTemperature': 61.15,
#     'dewPoint': 14.97,
#     'humidity': 0.16,
#     'pressure': 1023.9,
#     'windSpeed': 5.4,
#     'windGust': 8.69,
#     'windBearing': 58,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 262.4},
#    {'time': 1572548400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.28,
#     'apparentTemperature': 63.28,
#     'dewPoint': 15.85,
#     'humidity': 0.16,
#     'pressure': 1023.5,
#     'windSpeed': 4.95,
#     'windGust': 7.57,
#     'windBearing': 54,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 261.4},
#    {'time': 1572552000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.77,
#     'apparentTemperature': 65.77,
#     'dewPoint': 18.06,
#     'humidity': 0.16,
#     'pressure': 1022.7,
#     'windSpeed': 4.14,
#     'windGust': 5.95,
#     'windBearing': 41,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 260},
#    {'time': 1572555600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.83,
#     'apparentTemperature': 67.83,
#     'dewPoint': 20.39,
#     'humidity': 0.16,
#     'pressure': 1021.8,
#     'windSpeed': 3.62,
#     'windGust': 5.06,
#     'windBearing': 23,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'visibility': 10,
#     'ozone': 258.9},
#    {'time': 1572559200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.01,
#     'apparentTemperature': 69.01,
#     'dewPoint': 23.36,
#     'humidity': 0.18,
#     'pressure': 1021.3,
#     'windSpeed': 3.88,
#     'windGust': 5.68,
#     'windBearing': 3,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'visibility': 10,
#     'ozone': 258.7},
#    {'time': 1572562800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.3,
#     'apparentTemperature': 69.3,
#     'dewPoint': 26.94,
#     'humidity': 0.2,
#     'pressure': 1021,
#     'windSpeed': 4.66,
#     'windGust': 7.04,
#     'windBearing': 318,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 258.7},
#    {'time': 1572566400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 68.13,
#     'apparentTemperature': 68.13,
#     'dewPoint': 30.71,
#     'humidity': 0.25,
#     'pressure': 1020.7,
#     'windSpeed': 5.49,
#     'windGust': 8.04,
#     'windBearing': 293,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 258.5},
#    {'time': 1572570000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 65.39,
#     'apparentTemperature': 65.39,
#     'dewPoint': 34.1,
#     'humidity': 0.31,
#     'pressure': 1020.7,
#     'windSpeed': 5.92,
#     'windGust': 8.3,
#     'windBearing': 277,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 258.1},
#    {'time': 1572573600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.2,
#     'apparentTemperature': 62.2,
#     'dewPoint': 36.97,
#     'humidity': 0.39,
#     'pressure': 1020.9,
#     'windSpeed': 5.92,
#     'windGust': 8.17,
#     'windBearing': 285,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 257.5},
#    {'time': 1572577200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 60.38,
#     'apparentTemperature': 60.38,
#     'dewPoint': 38.95,
#     'humidity': 0.45,
#     'pressure': 1020.9,
#     'windSpeed': 5.64,
#     'windGust': 7.62,
#     'windBearing': 284,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 256.6},
#    {'time': 1572580800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.16,
#     'apparentTemperature': 59.16,
#     'dewPoint': 40.46,
#     'humidity': 0.5,
#     'pressure': 1021,
#     'windSpeed': 5.09,
#     'windGust': 6.48,
#     'windBearing': 306,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 255.2},
#    {'time': 1572584400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.27,
#     'apparentTemperature': 58.27,
#     'dewPoint': 41.69,
#     'humidity': 0.54,
#     'pressure': 1020.8,
#     'windSpeed': 4.44,
#     'windGust': 5.09,
#     'windBearing': 243,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 253.5},
#    {'time': 1572588000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.57,
#     'apparentTemperature': 57.57,
#     'dewPoint': 42.63,
#     'humidity': 0.57,
#     'pressure': 1020.7,
#     'windSpeed': 3.89,
#     'windGust': 4.17,
#     'windBearing': 268,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 252.2},
#    {'time': 1572591600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.92,
#     'apparentTemperature': 56.92,
#     'dewPoint': 43.02,
#     'humidity': 0.6,
#     'pressure': 1020.8,
#     'windSpeed': 3.54,
#     'windGust': 3.87,
#     'windBearing': 274,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 251.7},
#    {'time': 1572595200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.32,
#     'apparentTemperature': 56.32,
#     'dewPoint': 43.02,
#     'humidity': 0.61,
#     'pressure': 1020.8,
#     'windSpeed': 3.35,
#     'windGust': 3.84,
#     'windBearing': 226,
#     'cloudCover': 0.06,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 251.6},
#    {'time': 1572598800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.56,
#     'apparentTemperature': 55.56,
#     'dewPoint': 42.74,
#     'humidity': 0.62,
#     'pressure': 1020.8,
#     'windSpeed': 3.3,
#     'windGust': 3.82,
#     'windBearing': 195,
#     'cloudCover': 0.08,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 251.1},
#    {'time': 1572602400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.34,
#     'apparentTemperature': 54.34,
#     'dewPoint': 42.06,
#     'humidity': 0.63,
#     'pressure': 1020.7,
#     'windSpeed': 2.97,
#     'windGust': 3.64,
#     'windBearing': 307,
#     'cloudCover': 0.09,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 250},
#    {'time': 1572606000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 52.98,
#     'apparentTemperature': 52.98,
#     'dewPoint': 41.03,
#     'humidity': 0.64,
#     'pressure': 1020.5,
#     'windSpeed': 2.81,
#     'windGust': 3.38,
#     'windBearing': 111,
#     'cloudCover': 0.09,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 248.5},
#    {'time': 1572609600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 51.83,
#     'apparentTemperature': 51.83,
#     'dewPoint': 40.21,
#     'humidity': 0.64,
#     'pressure': 1020.4,
#     'windSpeed': 2.92,
#     'windGust': 3.31,
#     'windBearing': 104,
#     'cloudCover': 0.1,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 247.5},
#    {'time': 1572613200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 50.81,
#     'apparentTemperature': 50.81,
#     'dewPoint': 39.79,
#     'humidity': 0.66,
#     'pressure': 1020.4,
#     'windSpeed': 2.93,
#     'windGust': 3.41,
#     'windBearing': 50,
#     'cloudCover': 0.11,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 247},
#    {'time': 1572616800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 49.68,
#     'apparentTemperature': 49.68,
#     'dewPoint': 39.5,
#     'humidity': 0.68,
#     'pressure': 1020.5,
#     'windSpeed': 2.92,
#     'windGust': 3.5,
#     'windBearing': 36,
#     'cloudCover': 0.12,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 246.8},
#    {'time': 1572620400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 49.42,
#     'apparentTemperature': 49.42,
#     'dewPoint': 39.17,
#     'humidity': 0.68,
#     'pressure': 1020.8,
#     'windSpeed': 2.97,
#     'windGust': 3.57,
#     'windBearing': 34,
#     'cloudCover': 0.14,
#     'uvIndex': 0,
#     'visibility': 10,
#     'ozone': 247.6},
#    {'time': 1572624000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 51.23,
#     'apparentTemperature': 51.23,
#     'dewPoint': 38.94,
#     'humidity': 0.63,
#     'pressure': 1021.1,
#     'windSpeed': 2.87,
#     'windGust': 3.48,
#     'windBearing': 56,
#     'cloudCover': 0.14,
#     'uvIndex': 1,
#     'visibility': 10,
#     'ozone': 249.4}]},
#  'daily': {'summary': 'No precipitation throughout the week.',
#   'icon': 'clear-day',
#   'data': [{'time': 1572418800,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1572446040,
#     'sunsetTime': 1572484500,
#     'moonPhase': 0.11,
#     'precipIntensity': 0.0003,
#     'precipIntensityMax': 0.0017,
#     'precipIntensityMaxTime': 1572471000,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperatureHigh': 68.57,
#     'temperatureHighTime': 1572478080,
#     'temperatureLow': 51.7,
#     'temperatureLowTime': 1572532740,
#     'apparentTemperatureHigh': 68.07,
#     'apparentTemperatureHighTime': 1572478080,
#     'apparentTemperatureLow': 52.19,
#     'apparentTemperatureLowTime': 1572532740,
#     'dewPoint': 19.05,
#     'humidity': 0.22,
#     'pressure': 1020.4,
#     'windSpeed': 6.65,
#     'windGust': 16.43,
#     'windGustTime': 1572448920,
#     'windBearing': 58,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'uvIndexTime': 1572465180,
#     'visibility': 9.24,
#     'ozone': 270.4,
#     'temperatureMin': 51.95,
#     'temperatureMinTime': 1572447840,
#     'temperatureMax': 68.57,
#     'temperatureMaxTime': 1572478080,
#     'apparentTemperatureMin': 52.44,
#     'apparentTemperatureMinTime': 1572447840,
#     'apparentTemperatureMax': 68.07,
#     'apparentTemperatureMaxTime': 1572478080},
#    {'time': 1572505200,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1572532500,
#     'sunsetTime': 1572570840,
#     'moonPhase': 0.15,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1572533820,
#     'precipProbability': 0.01,
#     'precipType': 'rain',
#     'temperatureHigh': 69.85,
#     'temperatureHighTime': 1572561960,
#     'temperatureLow': 48.83,
#     'temperatureLowTime': 1572619380,
#     'apparentTemperatureHigh': 69.35,
#     'apparentTemperatureHighTime': 1572561960,
#     'apparentTemperatureLow': 49.32,
#     'apparentTemperatureLowTime': 1572619380,
#     'dewPoint': 27.86,
#     'humidity': 0.32,
#     'pressure': 1022.3,
#     'windSpeed': 4.92,
#     'windGust': 8.79,
#     'windGustTime': 1572543360,
#     'windBearing': 18,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'uvIndexTime': 1572551700,
#     'visibility': 10,
#     'ozone': 260.7,
#     'temperatureMin': 51.7,
#     'temperatureMinTime': 1572532740,
#     'temperatureMax': 69.85,
#     'temperatureMaxTime': 1572561960,
#     'apparentTemperatureMin': 52.19,
#     'apparentTemperatureMinTime': 1572532740,
#     'apparentTemperatureMax': 69.35,
#     'apparentTemperatureMaxTime': 1572561960},
#    {'time': 1572591600,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1572618960,
#     'sunsetTime': 1572657180,
#     'moonPhase': 0.18,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0004,
#     'precipIntensityMaxTime': 1572599700,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 67.75,
#     'temperatureHighTime': 1572645840,
#     'temperatureLow': 49.18,
#     'temperatureLowTime': 1572704160,
#     'apparentTemperatureHigh': 67.25,
#     'apparentTemperatureHighTime': 1572645840,
#     'apparentTemperatureLow': 47.98,
#     'apparentTemperatureLowTime': 1572703320,
#     'dewPoint': 41.03,
#     'humidity': 0.56,
#     'pressure': 1020.3,
#     'windSpeed': 3.34,
#     'windGust': 6.64,
#     'windGustTime': 1572654060,
#     'windBearing': 296,
#     'cloudCover': 0.08,
#     'uvIndex': 4,
#     'uvIndexTime': 1572638100,
#     'visibility': 10,
#     'ozone': 255.9,
#     'temperatureMin': 48.83,
#     'temperatureMinTime': 1572619380,
#     'temperatureMax': 67.75,
#     'temperatureMaxTime': 1572645840,
#     'apparentTemperatureMin': 49.32,
#     'apparentTemperatureMinTime': 1572619380,
#     'apparentTemperatureMax': 67.25,
#     'apparentTemperatureMaxTime': 1572645840},
#    {'time': 1572678000,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1572705480,
#     'sunsetTime': 1572743460,
#     'moonPhase': 0.21,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1572699660,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 68.66,
#     'temperatureHighTime': 1572732540,
#     'temperatureLow': 50.43,
#     'temperatureLowTime': 1572791040,
#     'apparentTemperatureHigh': 68.16,
#     'apparentTemperatureHighTime': 1572732540,
#     'apparentTemperatureLow': 50.92,
#     'apparentTemperatureLowTime': 1572791040,
#     'dewPoint': 37.65,
#     'humidity': 0.48,
#     'pressure': 1019.6,
#     'windSpeed': 4.05,
#     'windGust': 8.53,
#     'windGustTime': 1572742980,
#     'windBearing': 15,
#     'cloudCover': 0.09,
#     'uvIndex': 4,
#     'uvIndexTime': 1572724740,
#     'visibility': 10,
#     'ozone': 266.8,
#     'temperatureMin': 49.18,
#     'temperatureMinTime': 1572704160,
#     'temperatureMax': 68.66,
#     'temperatureMaxTime': 1572732540,
#     'apparentTemperatureMin': 47.98,
#     'apparentTemperatureMinTime': 1572703320,
#     'apparentTemperatureMax': 68.16,
#     'apparentTemperatureMaxTime': 1572732540},
#    {'time': 1572764400,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1572791940,
#     'sunsetTime': 1572829800,
#     'moonPhase': 0.24,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0,
#     'precipIntensityMaxTime': 1572773400,
#     'precipProbability': 0,
#     'temperatureHigh': 68.97,
#     'temperatureHighTime': 1572819240,
#     'temperatureLow': 49.99,
#     'temperatureLowTime': 1572877020,
#     'apparentTemperatureHigh': 68.47,
#     'apparentTemperatureHighTime': 1572819240,
#     'apparentTemperatureLow': 50.48,
#     'apparentTemperatureLowTime': 1572877020,
#     'dewPoint': 40.1,
#     'humidity': 0.51,
#     'pressure': 1016.8,
#     'windSpeed': 3.48,
#     'windGust': 9.03,
#     'windGustTime': 1572826860,
#     'windBearing': 337,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'uvIndexTime': 1572810900,
#     'visibility': 10,
#     'ozone': 277.5,
#     'temperatureMin': 50.43,
#     'temperatureMinTime': 1572791040,
#     'temperatureMax': 68.97,
#     'temperatureMaxTime': 1572819240,
#     'apparentTemperatureMin': 50.92,
#     'apparentTemperatureMinTime': 1572791040,
#     'apparentTemperatureMax': 68.47,
#     'apparentTemperatureMaxTime': 1572819240},
#    {'time': 1572854400,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1572878400,
#     'sunsetTime': 1572916140,
#     'moonPhase': 0.27,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1572903780,
#     'precipProbability': 0.02,
#     'precipType': 'rain',
#     'temperatureHigh': 69.25,
#     'temperatureHighTime': 1572905940,
#     'temperatureLow': 51.17,
#     'temperatureLowTime': 1572963540,
#     'apparentTemperatureHigh': 68.75,
#     'apparentTemperatureHighTime': 1572905940,
#     'apparentTemperatureLow': 51.66,
#     'apparentTemperatureLowTime': 1572963540,
#     'dewPoint': 41.97,
#     'humidity': 0.55,
#     'pressure': 1015.6,
#     'windSpeed': 3.39,
#     'windGust': 8.44,
#     'windGustTime': 1572913260,
#     'windBearing': 350,
#     'cloudCover': 0.14,
#     'uvIndex': 4,
#     'uvIndexTime': 1572897120,
#     'visibility': 10,
#     'ozone': 275.9,
#     'temperatureMin': 49.99,
#     'temperatureMinTime': 1572877020,
#     'temperatureMax': 69.25,
#     'temperatureMaxTime': 1572905940,
#     'apparentTemperatureMin': 50.48,
#     'apparentTemperatureMinTime': 1572877020,
#     'apparentTemperatureMax': 68.75,
#     'apparentTemperatureMaxTime': 1572905940},
#    {'time': 1572940800,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1572964860,
#     'sunsetTime': 1573002480,
#     'moonPhase': 0.3,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1572944400,
#     'precipProbability': 0.01,
#     'temperatureHigh': 70.71,
#     'temperatureHighTime': 1572994080,
#     'temperatureLow': 52.5,
#     'temperatureLowTime': 1573049880,
#     'apparentTemperatureHigh': 70.21,
#     'apparentTemperatureHighTime': 1572994080,
#     'apparentTemperatureLow': 52.99,
#     'apparentTemperatureLowTime': 1573049880,
#     'dewPoint': 42.34,
#     'humidity': 0.53,
#     'pressure': 1017.4,
#     'windSpeed': 3.78,
#     'windGust': 7.59,
#     'windGustTime': 1572999300,
#     'windBearing': 11,
#     'cloudCover': 0.1,
#     'uvIndex': 4,
#     'uvIndexTime': 1572983580,
#     'visibility': 10,
#     'ozone': 281.8,
#     'temperatureMin': 51.17,
#     'temperatureMinTime': 1572963540,
#     'temperatureMax': 70.71,
#     'temperatureMaxTime': 1572994080,
#     'apparentTemperatureMin': 51.66,
#     'apparentTemperatureMinTime': 1572963540,
#     'apparentTemperatureMax': 70.21,
#     'apparentTemperatureMaxTime': 1572994080},
#    {'time': 1573027200,
#     'summary': 'Clear throughout the day.',
#     'icon': 'clear-day',
#     'sunriseTime': 1573051320,
#     'sunsetTime': 1573088820,
#     'moonPhase': 0.33,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0004,
#     'precipIntensityMaxTime': 1573047000,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperatureHigh': 71.41,
#     'temperatureHighTime': 1573078920,
#     'temperatureLow': 52.4,
#     'temperatureLowTime': 1573137000,
#     'apparentTemperatureHigh': 70.91,
#     'apparentTemperatureHighTime': 1573078920,
#     'apparentTemperatureLow': 52.89,
#     'apparentTemperatureLowTime': 1573137000,
#     'dewPoint': 42.63,
#     'humidity': 0.52,
#     'pressure': 1017.1,
#     'windSpeed': 4.25,
#     'windGust': 9.82,
#     'windGustTime': 1573085220,
#     'windBearing': 8,
#     'cloudCover': 0.13,
#     'uvIndex': 4,
#     'uvIndexTime': 1573070040,
#     'visibility': 10,
#     'ozone': 286.7,
#     'temperatureMin': 52.5,
#     'temperatureMinTime': 1573049880,
#     'temperatureMax': 71.41,
#     'temperatureMaxTime': 1573078920,
#     'apparentTemperatureMin': 52.99,
#     'apparentTemperatureMinTime': 1573049880,
#     'apparentTemperatureMax': 70.91,
#     'apparentTemperatureMaxTime': 1573078920}]},
#  'flags': {'sources': ['nwspa',
#    'cmc',
#    'gfs',
#    'hrrr',
#    'icon',
#    'isd',
#    'madis',
#    'nam',
#    'sref',
#    'darksky'],
#   'nearest-station': 2.24,
#   'units': 'us'},
#  'offset': -7}

# %% [markdown]
# # Summary
#
# In this lab, we dug deep and used everything we've learned so far about python programming, databases, HTTP requests and API calls to ETL data from a SQL database into a MongoDB instance!
